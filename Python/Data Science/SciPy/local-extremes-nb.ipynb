# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import argrelmax, argrelmin

x = np.array([2, 1, 2, 2, 2, 1, 1, 0, 7, 4, 5, 8, 10, 11, 15, 10])
plt.plot(x)
plt.show()
#Maximum
print(argrelmax(x))
#Minumum
print(argrelmin(x))
# Out:
# (array([ 8, 14], dtype=int64),)
# (array([1, 7, 9], dtype=int64),)
